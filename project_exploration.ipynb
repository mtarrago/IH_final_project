# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('0171095-240321170329656.csv',sep="\t")

# %%
df.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3472778722  01d9098d-7dec-4235-b783-c537478cd4c2
# 1  3472778721  01d9098d-7dec-4235-b783-c537478cd4c2
# 2  3472778719  01d9098d-7dec-4235-b783-c537478cd4c2
# 3  3472778718  01d9098d-7dec-4235-b783-c537478cd4c2
# 4  3472778717  01d9098d-7dec-4235-b783-c537478cd4c2
#
#                            occurrenceID   kingdom    phylum     class  \
# 0  82e3ca29-e5f6-24f6-e053-2614a8c008ee  Animalia  Chordata  Mammalia
# 1  82e3ca25-dddf-24f6-e053-2614a8c008ee  Animalia  Chordata  Mammalia
# 2  82e3ca29-d3af-24f6-e053-2614a8c008ee  Animalia  Chordata  Mammalia
# 3  82e3ca29-dc60-24f6-e053-2614a8c008ee  Animalia  Chordata  Mammalia
# 4  82e3ca29-cce9-24f6-e053-2614a8c008ee  Animalia  Chordata  Mammalia
#
#        order       family         genus                species  ...  \
# 0  Carnivora     Phocidae   Halichoerus     Halichoerus grypus  ...
# 1  Carnivora     Phocidae   Halichoerus     Halichoerus grypus  ...
# ...

# %%
df.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
df.genus.unique()
# Out:
# array(['Halichoerus', 'Tursiops', 'Globicephala', 'Stenella', 'Phocoena',
#        'Megaptera', 'Physeter', 'Balaenoptera', 'Delphinus',
#        'Arctocephalus', 'Orcinus', 'Grampus', 'Phoca', 'Dugong',
#        'Mesoplodon', 'Mirounga', 'Pseudorca', 'Peponocephala', 'Ziphius',
#        'Lagenodelphis', 'Steno', 'Hyperoodon', 'Kogia', 'Cystophora',
#        'Cephalorhynchus', 'Lagenorhynchus', 'Eubalaena', 'Indopacetus',
#        'Pagophilus', 'Hydrurga', 'Pusa', 'Feresa', 'Monachus',
#        'Trichechus', 'Sotalia', 'Lissodelphis', 'Erignathus',
#        'Delphinapterus', 'Sousa'], dtype=object)

# %%
df['day'].isna().value_counts()
# Out:
# False    10686
# True      5697
# Name: day, dtype: int64

# %%
df2 = pd.read_csv('0171071-240321170329656/occurrence.txt', sep='\t')
df2.head()
# Out:
#        gbifID  accessRights  bibliographicCitation language    license  \
# 0  3471241301           NaN                    NaN  fr | en  CC_BY_4_0
# 1  3471241302           NaN                    NaN  fr | en  CC_BY_4_0
# 2  2487821601           NaN                    NaN  fr | en  CC_BY_4_0
# 3  2487821602           NaN                    NaN  fr | en  CC_BY_4_0
# 4  2487821603           NaN                    NaN  fr | en  CC_BY_4_0
#
#    modified                            publisher  references  rightsHolder  \
# 0       NaN  UMS PatriNat (OFB-CNRS-MNHN), Paris         NaN           NaN
# 1       NaN  UMS PatriNat (OFB-CNRS-MNHN), Paris         NaN           NaN
# 2       NaN  UMS PatriNat (OFB-CNRS-MNHN), Paris         NaN           NaN
# 3       NaN  UMS PatriNat (OFB-CNRS-MNHN), Paris         NaN           NaN
# 4       NaN  UMS PatriNat (OFB-CNRS-MNHN), Paris         NaN           NaN
#
#    type  ...  publishedByGbifRegion  level0Gid level0Name  level1Gid  \
# ...

# %%
df2.columns
# Out:
# Index(['gbifID', 'accessRights', 'bibliographicCitation', 'language',
#        'license', 'modified', 'publisher', 'references', 'rightsHolder',
#        'type',
#        ...
#        'publishedByGbifRegion', 'level0Gid', 'level0Name', 'level1Gid',
#        'level1Name', 'level2Gid', 'level2Name', 'level3Gid', 'level3Name',
#        'iucnRedListCategory'],
#       dtype='object', length=223)

# %%
df.genus.isna().value_counts()
# Out:
# False    16383
# Name: genus, dtype: int64

# %%
df3 = pd.read_csv('0171246-240321170329656.csv', sep='\t')

# %%
df3.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3931089248  e357cdec-295a-4b91-ac7d-abf5fbbc43bb
# 1  3931479837  e357cdec-295a-4b91-ac7d-abf5fbbc43bb
# 2  3931098375  e357cdec-295a-4b91-ac7d-abf5fbbc43bb
# 3  3931098378  e357cdec-295a-4b91-ac7d-abf5fbbc43bb
# 4  3931479941  e357cdec-295a-4b91-ac7d-abf5fbbc43bb
#
#                            occurrenceID   kingdom    phylum     class  \
# 0  8b016eb5-524e-4925-8242-1f8971e05ac3  Animalia  Chordata  Mammalia
# 1  8b0f2a75-eb19-4661-97b4-564029f50093  Animalia  Chordata  Mammalia
# 2  8b2ce4d8-f309-4af7-9305-bb4da87c2839  Animalia  Chordata  Mammalia
# 3  8b2e5fc0-5f03-4009-b704-d4d4494b7b7d  Animalia  Chordata  Mammalia
# 4  8b37224e-4768-4388-8d42-15c29546d864  Animalia  Chordata  Mammalia
#
#             order         family      genus              species  ...  \
# 0        Rodentia       Gliridae    Eliomys    Eliomys quercinus  ...
# 1  Erinaceomorpha    Erinaceidae  Erinaceus  Erinaceus europaeus  ...
# ...

# %%
df3['species'].nunique()/len(df3['species'])
# Out:
# 0.0010581160177334887

# %%
df3.year.value_counts()
# Out:
# 2020    74661
# Name: year, dtype: int64

# %%
df4 = pd.read_csv('0171389-240321170329656.csv', sep='\t')

# %%
df4.head()
# Out:
#        gbifID                            datasetKey  \
# 0  4550088120  256b9877-cef3-4e8e-84e1-f23299c49655
# 1  4550088160  256b9877-cef3-4e8e-84e1-f23299c49655
# 2  4550088174  256b9877-cef3-4e8e-84e1-f23299c49655
# 3  4550088192  256b9877-cef3-4e8e-84e1-f23299c49655
# 4  4550088210  256b9877-cef3-4e8e-84e1-f23299c49655
#
#                            occurrenceID   kingdom    phylum     class  \
# 0  ded4571c-d43e-41eb-85fd-00c00041ac57  Animalia  Chordata  Mammalia
# 1  dee68c06-9091-41ec-9fd9-021000194424  Animalia  Chordata  Mammalia
# 2  def042b0-80a2-41eb-aae5-01f000135055  Animalia  Chordata  Mammalia
# 3  defb621a-1c59-41ec-9cbe-00b0001a12e9  Animalia  Chordata  Mammalia
# 4  df02426b-f478-41eb-af7e-0410066432f2  Animalia  Chordata  Mammalia
#
#           order         family      genus              species  ...  \
# 0     Carnivora     Mustelidae     Martes         Martes foina  ...
# 1      Rodentia      Sciuridae    Sciurus     Sciurus vulgaris  ...
# ...

# %%
df4.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
df.year.unique()
# Out:
# array([2012.,   nan, 2010., 2014., 2008., 2013., 2011., 2000., 2005.,
#        2009., 2002., 2001., 2003., 2006., 2004., 2007., 2015., 2016.])

# %%
df.year.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df5 = pd.read_csv('archive-2/species.csv')
df5.head()
# Out:
# /Users/Mariona/Library/CloudStorage/GoogleDrive-ona.tarrago@gmail.com/La meva unitat/IRONHACK_DATA_ANALYST/IH_final_project/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   species_id             park_name category         order    family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           scientific_name                                       common_names  \
# 0             Alces alces                                              Moose
# ...

# %%
df5["category"].value_counts()
# Out:
# Vascular Plant         65221
# Bird                   14601
# Insect                 14349
# Fungi                   6203
# Nonvascular Plant       4278
# Fish                    3956
# Mammal                  3867
# Invertebrate            1566
# Reptile                 1343
# Algae                    976
# Slug/Snail               787
# Spider/Scorpion          776
# Amphibian                743
# Crab/Lobster/Shrimp      582
# Name: category, dtype: int64

# %%
df5.shape
# Out:
# (119248, 14)

# %%
df5.isna().sum()
# Out:
# species_id                  0
# park_name                   0
# category                    0
# order                    1472
# family                   1512
# scientific_name             0
# common_names                0
# record_status               0
# occurrence              20142
# nativeness              25045
# abundance               42942
# seasonality             99091
# conservation_status    114530
# Unnamed: 13            119243
# dtype: int64

# %%
df5.duplicated().sum()
# Out:
# 0
